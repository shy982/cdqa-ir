# %%
from langchain.embeddings import LlamaCppEmbeddings
from langchain.llms import LlamaCpp
from langchain.prompts import ChatPromptTemplate
from langchain.schema.runnable import RunnablePassthrough
from langchain.schema.output_parser import StrOutputParser
from langchain.vectorstores import FAISS
from nltk.tokenize import word_tokenize
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction
from rouge_score import rouge_scorer
from tqdm import tqdm

import pickle

# %%
llm = LlamaCpp(
    model_path="./backups/llama.cpp/models/llama-2-7b-chat.ggmlv3.q4_K_S.gguf.bin", 
    n_ctx=2048)
llm.client.verbose = False
# Out:
# llama_model_loader: loaded meta data with 19 key-value pairs and 291 tensors from ./backups/llama.cpp/models/llama-2-7b-chat.ggmlv3.q4_K_S.gguf.bin (version unknown)
# llama_model_loader: - tensor    0:                token_embd.weight q4_K     [  4096, 32000,     1,     1 ]
# llama_model_loader: - tensor    1:               output_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor    2:                    output.weight q6_K     [  4096, 32000,     1,     1 ]
# llama_model_loader: - tensor    3:              blk.0.attn_q.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor    4:              blk.0.attn_k.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor    5:              blk.0.attn_v.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor    6:         blk.0.attn_output.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor    7:           blk.0.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor    8:            blk.0.ffn_gate.weight q4_K     [  4096, 11008,     1,     1 ]
# llama_model_loader: - tensor    9:            blk.0.ffn_down.weight q4_K     [ 11008,  4096,     1,     1 ]
# llama_model_loader: - tensor   10:              blk.0.ffn_up.weight q4_K     [  4096, 11008,     1,     1 ]
# llama_model_loader: - tensor   11:            blk.0.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor   12:              blk.1.attn_q.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   13:              blk.1.attn_k.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   14:              blk.1.attn_v.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   15:         blk.1.attn_output.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   16:           blk.1.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor   17:            blk.1.ffn_gate.weight q4_K     [  4096, 11008,     1,     1 ]
# llama_model_loader: - tensor   18:            blk.1.ffn_down.weight q4_K     [ 11008,  4096,     1,     1 ]
# llama_model_loader: - tensor   19:              blk.1.ffn_up.weight q4_K     [  4096, 11008,     1,     1 ]
# llama_model_loader: - tensor   20:            blk.1.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor   21:              blk.2.attn_q.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   22:              blk.2.attn_k.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   23:              blk.2.attn_v.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   24:         blk.2.attn_output.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   25:           blk.2.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor   26:            blk.2.ffn_gate.weight q4_K     [  4096, 11008,     1,     1 ]
# llama_model_loader: - tensor   27:            blk.2.ffn_down.weight q4_K     [ 11008,  4096,     1,     1 ]
# llama_model_loader: - tensor   28:              blk.2.ffn_up.weight q4_K     [  4096, 11008,     1,     1 ]
# llama_model_loader: - tensor   29:            blk.2.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor   30:              blk.3.attn_q.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   31:              blk.3.attn_k.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   32:              blk.3.attn_v.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   33:         blk.3.attn_output.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   34:           blk.3.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor   35:            blk.3.ffn_gate.weight q4_K     [  4096, 11008,     1,     1 ]
# llama_model_loader: - tensor   36:            blk.3.ffn_down.weight q4_K     [ 11008,  4096,     1,     1 ]
# llama_model_loader: - tensor   37:              blk.3.ffn_up.weight q4_K     [  4096, 11008,     1,     1 ]
# llama_model_loader: - tensor   38:            blk.3.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor   39:              blk.4.attn_q.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   40:              blk.4.attn_k.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   41:              blk.4.attn_v.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   42:         blk.4.attn_output.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   43:           blk.4.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor   44:            blk.4.ffn_gate.weight q4_K     [  4096, 11008,     1,     1 ]
# llama_model_loader: - tensor   45:            blk.4.ffn_down.weight q4_K     [ 11008,  4096,     1,     1 ]
# llama_model_loader: - tensor   46:              blk.4.ffn_up.weight q4_K     [  4096, 11008,     1,     1 ]
# llama_model_loader: - tensor   47:            blk.4.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor   48:              blk.5.attn_q.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   49:              blk.5.attn_k.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   50:              blk.5.attn_v.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   51:         blk.5.attn_output.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   52:           blk.5.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor   53:            blk.5.ffn_gate.weight q4_K     [  4096, 11008,     1,     1 ]
# llama_model_loader: - tensor   54:            blk.5.ffn_down.weight q4_K     [ 11008,  4096,     1,     1 ]
# llama_model_loader: - tensor   55:              blk.5.ffn_up.weight q4_K     [  4096, 11008,     1,     1 ]
# llama_model_loader: - tensor   56:            blk.5.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor   57:              blk.6.attn_q.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   58:              blk.6.attn_k.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   59:              blk.6.attn_v.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   60:         blk.6.attn_output.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   61:           blk.6.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor   62:            blk.6.ffn_gate.weight q4_K     [  4096, 11008,     1,     1 ]
# llama_model_loader: - tensor   63:            blk.6.ffn_down.weight q4_K     [ 11008,  4096,     1,     1 ]
# llama_model_loader: - tensor   64:              blk.6.ffn_up.weight q4_K     [  4096, 11008,     1,     1 ]
# llama_model_loader: - tensor   65:            blk.6.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor   66:              blk.7.attn_q.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   67:              blk.7.attn_k.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   68:              blk.7.attn_v.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   69:         blk.7.attn_output.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   70:           blk.7.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor   71:            blk.7.ffn_gate.weight q4_K     [  4096, 11008,     1,     1 ]
# llama_model_loader: - tensor   72:            blk.7.ffn_down.weight q4_K     [ 11008,  4096,     1,     1 ]
# llama_model_loader: - tensor   73:              blk.7.ffn_up.weight q4_K     [  4096, 11008,     1,     1 ]
# llama_model_loader: - tensor   74:            blk.7.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor   75:              blk.8.attn_q.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   76:              blk.8.attn_k.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   77:              blk.8.attn_v.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   78:         blk.8.attn_output.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   79:           blk.8.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor   80:            blk.8.ffn_gate.weight q4_K     [  4096, 11008,     1,     1 ]
# llama_model_loader: - tensor   81:            blk.8.ffn_down.weight q4_K     [ 11008,  4096,     1,     1 ]
# llama_model_loader: - tensor   82:              blk.8.ffn_up.weight q4_K     [  4096, 11008,     1,     1 ]
# llama_model_loader: - tensor   83:            blk.8.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor   84:              blk.9.attn_q.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   85:              blk.9.attn_k.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   86:              blk.9.attn_v.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   87:         blk.9.attn_output.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   88:           blk.9.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor   89:            blk.9.ffn_gate.weight q4_K     [  4096, 11008,     1,     1 ]
# llama_model_loader: - tensor   90:            blk.9.ffn_down.weight q4_K     [ 11008,  4096,     1,     1 ]
# llama_model_loader: - tensor   91:              blk.9.ffn_up.weight q4_K     [  4096, 11008,     1,     1 ]
# llama_model_loader: - tensor   92:            blk.9.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor   93:             blk.10.attn_q.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   94:             blk.10.attn_k.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   95:             blk.10.attn_v.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   96:        blk.10.attn_output.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor   97:          blk.10.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor   98:           blk.10.ffn_gate.weight q4_K     [  4096, 11008,     1,     1 ]
# llama_model_loader: - tensor   99:           blk.10.ffn_down.weight q4_K     [ 11008,  4096,     1,     1 ]
# llama_model_loader: - tensor  100:             blk.10.ffn_up.weight q4_K     [  4096, 11008,     1,     1 ]
# llama_model_loader: - tensor  101:           blk.10.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  102:             blk.11.attn_q.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  103:             blk.11.attn_k.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  104:             blk.11.attn_v.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  105:        blk.11.attn_output.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  106:          blk.11.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  107:           blk.11.ffn_gate.weight q4_K     [  4096, 11008,     1,     1 ]
# llama_model_loader: - tensor  108:           blk.11.ffn_down.weight q4_K     [ 11008,  4096,     1,     1 ]
# llama_model_loader: - tensor  109:             blk.11.ffn_up.weight q4_K     [  4096, 11008,     1,     1 ]
# llama_model_loader: - tensor  110:           blk.11.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  111:             blk.12.attn_q.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  112:             blk.12.attn_k.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  113:             blk.12.attn_v.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  114:        blk.12.attn_output.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  115:          blk.12.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  116:           blk.12.ffn_gate.weight q4_K     [  4096, 11008,     1,     1 ]
# llama_model_loader: - tensor  117:           blk.12.ffn_down.weight q4_K     [ 11008,  4096,     1,     1 ]
# llama_model_loader: - tensor  118:             blk.12.ffn_up.weight q4_K     [  4096, 11008,     1,     1 ]
# llama_model_loader: - tensor  119:           blk.12.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  120:             blk.13.attn_q.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  121:             blk.13.attn_k.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  122:             blk.13.attn_v.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  123:        blk.13.attn_output.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  124:          blk.13.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  125:           blk.13.ffn_gate.weight q4_K     [  4096, 11008,     1,     1 ]
# llama_model_loader: - tensor  126:           blk.13.ffn_down.weight q4_K     [ 11008,  4096,     1,     1 ]
# llama_model_loader: - tensor  127:             blk.13.ffn_up.weight q4_K     [  4096, 11008,     1,     1 ]
# llama_model_loader: - tensor  128:           blk.13.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  129:             blk.14.attn_q.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  130:             blk.14.attn_k.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  131:             blk.14.attn_v.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  132:        blk.14.attn_output.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  133:          blk.14.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  134:           blk.14.ffn_gate.weight q4_K     [  4096, 11008,     1,     1 ]
# llama_model_loader: - tensor  135:           blk.14.ffn_down.weight q4_K     [ 11008,  4096,     1,     1 ]
# llama_model_loader: - tensor  136:             blk.14.ffn_up.weight q4_K     [  4096, 11008,     1,     1 ]
# llama_model_loader: - tensor  137:           blk.14.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  138:             blk.15.attn_q.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  139:             blk.15.attn_k.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  140:             blk.15.attn_v.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  141:        blk.15.attn_output.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  142:          blk.15.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  143:           blk.15.ffn_gate.weight q4_K     [  4096, 11008,     1,     1 ]
# llama_model_loader: - tensor  144:           blk.15.ffn_down.weight q4_K     [ 11008,  4096,     1,     1 ]
# llama_model_loader: - tensor  145:             blk.15.ffn_up.weight q4_K     [  4096, 11008,     1,     1 ]
# llama_model_loader: - tensor  146:           blk.15.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  147:             blk.16.attn_q.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  148:             blk.16.attn_k.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  149:             blk.16.attn_v.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  150:        blk.16.attn_output.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  151:          blk.16.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  152:           blk.16.ffn_gate.weight q4_K     [  4096, 11008,     1,     1 ]
# llama_model_loader: - tensor  153:           blk.16.ffn_down.weight q4_K     [ 11008,  4096,     1,     1 ]
# llama_model_loader: - tensor  154:             blk.16.ffn_up.weight q4_K     [  4096, 11008,     1,     1 ]
# llama_model_loader: - tensor  155:           blk.16.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  156:             blk.17.attn_q.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  157:             blk.17.attn_k.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  158:             blk.17.attn_v.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  159:        blk.17.attn_output.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  160:          blk.17.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  161:           blk.17.ffn_gate.weight q4_K     [  4096, 11008,     1,     1 ]
# llama_model_loader: - tensor  162:           blk.17.ffn_down.weight q4_K     [ 11008,  4096,     1,     1 ]
# llama_model_loader: - tensor  163:             blk.17.ffn_up.weight q4_K     [  4096, 11008,     1,     1 ]
# llama_model_loader: - tensor  164:           blk.17.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  165:             blk.18.attn_q.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  166:             blk.18.attn_k.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  167:             blk.18.attn_v.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  168:        blk.18.attn_output.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  169:          blk.18.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  170:           blk.18.ffn_gate.weight q4_K     [  4096, 11008,     1,     1 ]
# llama_model_loader: - tensor  171:           blk.18.ffn_down.weight q4_K     [ 11008,  4096,     1,     1 ]
# llama_model_loader: - tensor  172:             blk.18.ffn_up.weight q4_K     [  4096, 11008,     1,     1 ]
# llama_model_loader: - tensor  173:           blk.18.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  174:             blk.19.attn_q.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  175:             blk.19.attn_k.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  176:             blk.19.attn_v.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  177:        blk.19.attn_output.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  178:          blk.19.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  179:           blk.19.ffn_gate.weight q4_K     [  4096, 11008,     1,     1 ]
# llama_model_loader: - tensor  180:           blk.19.ffn_down.weight q4_K     [ 11008,  4096,     1,     1 ]
# llama_model_loader: - tensor  181:             blk.19.ffn_up.weight q4_K     [  4096, 11008,     1,     1 ]
# llama_model_loader: - tensor  182:           blk.19.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  183:             blk.20.attn_q.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  184:             blk.20.attn_k.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  185:             blk.20.attn_v.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  186:        blk.20.attn_output.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  187:          blk.20.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  188:           blk.20.ffn_gate.weight q4_K     [  4096, 11008,     1,     1 ]
# llama_model_loader: - tensor  189:           blk.20.ffn_down.weight q4_K     [ 11008,  4096,     1,     1 ]
# llama_model_loader: - tensor  190:             blk.20.ffn_up.weight q4_K     [  4096, 11008,     1,     1 ]
# llama_model_loader: - tensor  191:           blk.20.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  192:             blk.21.attn_q.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  193:             blk.21.attn_k.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  194:             blk.21.attn_v.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  195:        blk.21.attn_output.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  196:          blk.21.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  197:           blk.21.ffn_gate.weight q4_K     [  4096, 11008,     1,     1 ]
# llama_model_loader: - tensor  198:           blk.21.ffn_down.weight q4_K     [ 11008,  4096,     1,     1 ]
# llama_model_loader: - tensor  199:             blk.21.ffn_up.weight q4_K     [  4096, 11008,     1,     1 ]
# llama_model_loader: - tensor  200:           blk.21.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  201:             blk.22.attn_q.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  202:             blk.22.attn_k.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  203:             blk.22.attn_v.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  204:        blk.22.attn_output.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  205:          blk.22.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  206:           blk.22.ffn_gate.weight q4_K     [  4096, 11008,     1,     1 ]
# llama_model_loader: - tensor  207:           blk.22.ffn_down.weight q4_K     [ 11008,  4096,     1,     1 ]
# llama_model_loader: - tensor  208:             blk.22.ffn_up.weight q4_K     [  4096, 11008,     1,     1 ]
# llama_model_loader: - tensor  209:           blk.22.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  210:             blk.23.attn_q.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  211:             blk.23.attn_k.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  212:             blk.23.attn_v.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  213:        blk.23.attn_output.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  214:          blk.23.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  215:           blk.23.ffn_gate.weight q4_K     [  4096, 11008,     1,     1 ]
# llama_model_loader: - tensor  216:           blk.23.ffn_down.weight q4_K     [ 11008,  4096,     1,     1 ]
# llama_model_loader: - tensor  217:             blk.23.ffn_up.weight q4_K     [  4096, 11008,     1,     1 ]
# llama_model_loader: - tensor  218:           blk.23.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  219:             blk.24.attn_q.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  220:             blk.24.attn_k.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  221:             blk.24.attn_v.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  222:        blk.24.attn_output.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  223:          blk.24.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  224:           blk.24.ffn_gate.weight q4_K     [  4096, 11008,     1,     1 ]
# llama_model_loader: - tensor  225:           blk.24.ffn_down.weight q4_K     [ 11008,  4096,     1,     1 ]
# llama_model_loader: - tensor  226:             blk.24.ffn_up.weight q4_K     [  4096, 11008,     1,     1 ]
# llama_model_loader: - tensor  227:           blk.24.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  228:             blk.25.attn_q.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  229:             blk.25.attn_k.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  230:             blk.25.attn_v.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  231:        blk.25.attn_output.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  232:          blk.25.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  233:           blk.25.ffn_gate.weight q4_K     [  4096, 11008,     1,     1 ]
# llama_model_loader: - tensor  234:           blk.25.ffn_down.weight q4_K     [ 11008,  4096,     1,     1 ]
# llama_model_loader: - tensor  235:             blk.25.ffn_up.weight q4_K     [  4096, 11008,     1,     1 ]
# llama_model_loader: - tensor  236:           blk.25.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  237:             blk.26.attn_q.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  238:             blk.26.attn_k.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  239:             blk.26.attn_v.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  240:        blk.26.attn_output.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  241:          blk.26.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  242:           blk.26.ffn_gate.weight q4_K     [  4096, 11008,     1,     1 ]
# llama_model_loader: - tensor  243:           blk.26.ffn_down.weight q4_K     [ 11008,  4096,     1,     1 ]
# llama_model_loader: - tensor  244:             blk.26.ffn_up.weight q4_K     [  4096, 11008,     1,     1 ]
# llama_model_loader: - tensor  245:           blk.26.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  246:             blk.27.attn_q.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  247:             blk.27.attn_k.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  248:             blk.27.attn_v.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  249:        blk.27.attn_output.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  250:          blk.27.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  251:           blk.27.ffn_gate.weight q4_K     [  4096, 11008,     1,     1 ]
# llama_model_loader: - tensor  252:           blk.27.ffn_down.weight q4_K     [ 11008,  4096,     1,     1 ]
# llama_model_loader: - tensor  253:             blk.27.ffn_up.weight q4_K     [  4096, 11008,     1,     1 ]
# llama_model_loader: - tensor  254:           blk.27.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  255:             blk.28.attn_q.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  256:             blk.28.attn_k.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  257:             blk.28.attn_v.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  258:        blk.28.attn_output.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  259:          blk.28.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  260:           blk.28.ffn_gate.weight q4_K     [  4096, 11008,     1,     1 ]
# llama_model_loader: - tensor  261:           blk.28.ffn_down.weight q4_K     [ 11008,  4096,     1,     1 ]
# llama_model_loader: - tensor  262:             blk.28.ffn_up.weight q4_K     [  4096, 11008,     1,     1 ]
# llama_model_loader: - tensor  263:           blk.28.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  264:             blk.29.attn_q.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  265:             blk.29.attn_k.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  266:             blk.29.attn_v.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  267:        blk.29.attn_output.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  268:          blk.29.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  269:           blk.29.ffn_gate.weight q4_K     [  4096, 11008,     1,     1 ]
# llama_model_loader: - tensor  270:           blk.29.ffn_down.weight q4_K     [ 11008,  4096,     1,     1 ]
# llama_model_loader: - tensor  271:             blk.29.ffn_up.weight q4_K     [  4096, 11008,     1,     1 ]
# llama_model_loader: - tensor  272:           blk.29.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  273:             blk.30.attn_q.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  274:             blk.30.attn_k.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  275:             blk.30.attn_v.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  276:        blk.30.attn_output.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  277:          blk.30.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  278:           blk.30.ffn_gate.weight q4_K     [  4096, 11008,     1,     1 ]
# llama_model_loader: - tensor  279:           blk.30.ffn_down.weight q4_K     [ 11008,  4096,     1,     1 ]
# llama_model_loader: - tensor  280:             blk.30.ffn_up.weight q4_K     [  4096, 11008,     1,     1 ]
# llama_model_loader: - tensor  281:           blk.30.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  282:             blk.31.attn_q.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  283:             blk.31.attn_k.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  284:             blk.31.attn_v.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  285:        blk.31.attn_output.weight q4_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor  286:          blk.31.attn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - tensor  287:           blk.31.ffn_gate.weight q4_K     [  4096, 11008,     1,     1 ]
# llama_model_loader: - tensor  288:           blk.31.ffn_down.weight q4_K     [ 11008,  4096,     1,     1 ]
# llama_model_loader: - tensor  289:             blk.31.ffn_up.weight q4_K     [  4096, 11008,     1,     1 ]
# llama_model_loader: - tensor  290:           blk.31.ffn_norm.weight f32      [  4096,     1,     1,     1 ]
# llama_model_loader: - kv   0:                       general.architecture str
# llama_model_loader: - kv   1:                               general.name str
# llama_model_loader: - kv   2:                        general.description str
# llama_model_loader: - kv   3:                          general.file_type u32
# llama_model_loader: - kv   4:                       llama.context_length u32
# llama_model_loader: - kv   5:                     llama.embedding_length u32
# llama_model_loader: - kv   6:                          llama.block_count u32
# llama_model_loader: - kv   7:                  llama.feed_forward_length u32
# llama_model_loader: - kv   8:                 llama.rope.dimension_count u32
# llama_model_loader: - kv   9:                 llama.attention.head_count u32
# llama_model_loader: - kv  10:              llama.attention.head_count_kv u32
# llama_model_loader: - kv  11:     llama.attention.layer_norm_rms_epsilon f32
# llama_model_loader: - kv  12:                       tokenizer.ggml.model str
# llama_model_loader: - kv  13:                      tokenizer.ggml.tokens arr
# llama_model_loader: - kv  14:                      tokenizer.ggml.scores arr
# llama_model_loader: - kv  15:                  tokenizer.ggml.token_type arr
# llama_model_loader: - kv  16:            tokenizer.ggml.unknown_token_id u32
# llama_model_loader: - kv  17:                tokenizer.ggml.bos_token_id u32
# llama_model_loader: - kv  18:                tokenizer.ggml.eos_token_id u32
# llama_model_loader: - type  f32:   65 tensors
# llama_model_loader: - type q4_K:  225 tensors
# llama_model_loader: - type q6_K:    1 tensors
# llm_load_print_meta: format           = unknown
# llm_load_print_meta: arch             = llama
# llm_load_print_meta: vocab type       = SPM
# llm_load_print_meta: n_vocab          = 32000
# llm_load_print_meta: n_merges         = 0
# llm_load_print_meta: n_ctx_train      = 2048
# llm_load_print_meta: n_embd           = 4096
# llm_load_print_meta: n_head           = 32
# llm_load_print_meta: n_head_kv        = 32
# llm_load_print_meta: n_layer          = 32
# llm_load_print_meta: n_rot            = 128
# llm_load_print_meta: n_gqa            = 1
# llm_load_print_meta: f_norm_eps       = 0.0e+00
# llm_load_print_meta: f_norm_rms_eps   = 1.0e-05
# llm_load_print_meta: n_ff             = 11008
# llm_load_print_meta: freq_base_train  = 10000.0
# llm_load_print_meta: freq_scale_train = 1
# llm_load_print_meta: model type       = 7B
# llm_load_print_meta: model ftype      = mostly Q4_K - Small
# llm_load_print_meta: model params     = 6.74 B
# llm_load_print_meta: model size       = 3.56 GiB (4.54 BPW)
# llm_load_print_meta: general.name   = llama-2-7b-chat.ggmlv3.q4_K_S.bin
# llm_load_print_meta: BOS token = 1 '<s>'
# llm_load_print_meta: EOS token = 2 '</s>'
# llm_load_print_meta: UNK token = 0 '<unk>'
# llm_load_print_meta: LF token  = 13 '<0x0A>'
# llm_load_tensors: ggml ctx size =    0.09 MB
# llm_load_tensors: mem required  = 3647.96 MB
# ..................................................................................................
# llama_new_context_with_model: n_ctx      = 2048
# llama_new_context_with_model: freq_base  = 10000.0
# llama_new_context_with_model: freq_scale = 1
# llama_new_context_with_model: kv self size  = 1024.00 MB
# llama_new_context_with_model: compute buffer total size = 8.31 MB
# AVX = 0 | AVX2 = 0 | AVX512 = 0 | AVX512_VBMI = 0 | AVX512_VNNI = 0 | FMA = 0 | NEON = 1 | ARM_FMA = 1 | F16C = 0 | FP16_VA = 1 | WASM_SIMD = 0 | BLAS = 1 | SSE3 = 0 | SSSE3 = 0 | VSX = 0 |

# %%
def tokenizer(text):
    return word_tokenize(text.lower())

# %%
queries = {}

idx = None
with open("../data/cisi/CISI.QRY") as f:
    for query in f.read().split(".I"):
        for i, line in enumerate(query.split("\n")):
            if not line:
                continue
            elif i == 0:
                idx = int(line)
                queries[idx] = ""
            elif not line.startswith("."):
                queries[idx] += " "+line

# %%
# queries

# %%
answers_llama = {}
for idx, qry in tqdm(queries.items()):
    answers_llama[idx] = llm(qry)
# Out:
#   0%|                                                                | 0/112 [00:00<?, ?it/s]Llama.generate: prefix-match hit
#   1%|▌                                                       | 1/112 [00:13<25:52, 13.98s/it]
# llama_print_timings:        load time =  6919.55 ms
# llama_print_timings:      sample time =   179.99 ms /   256 runs   (    0.70 ms per token,  1422.32 tokens per second)
# llama_print_timings: prompt eval time =     0.00 ms /     1 tokens (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:        eval time = 13430.61 ms /   256 runs   (   52.46 ms per token,    19.06 tokens per second)
# llama_print_timings:       total time = 13979.15 ms
# Llama.generate: prefix-match hit
#   2%|█                                                       | 2/112 [00:29<27:07, 14.79s/it]
# llama_print_timings:        load time =  6919.55 ms
# llama_print_timings:      sample time =   180.58 ms /   256 runs   (    0.71 ms per token,  1417.65 tokens per second)
# llama_print_timings: prompt eval time =  1150.65 ms /    24 tokens (   47.94 ms per token,    20.86 tokens per second)
# llama_print_timings:        eval time = 13653.12 ms /   256 runs   (   53.33 ms per token,    18.75 tokens per second)
# llama_print_timings:       total time = 15355.61 ms
# Llama.generate: prefix-match hit
#   3%|█▌                                                      | 3/112 [00:43<26:45, 14.73s/it]
# llama_print_timings:        load time =  6919.55 ms
# llama_print_timings:      sample time =   180.83 ms /   256 runs   (    0.71 ms per token,  1415.68 tokens per second)
# llama_print_timings: prompt eval time =   528.25 ms /    11 tokens (   48.02 ms per token,    20.82 tokens per second)
# llama_print_timings:        eval time = 13579.27 ms /   255 runs   (   53.25 ms per token,    18.78 tokens per second)
# llama_print_timings:       total time = 14656.78 ms
# Llama.generate: prefix-match hit
#   4%|██                                                      | 4/112 [00:56<25:00, 13.89s/it]
# llama_print_timings:        load time =  6919.55 ms
# llama_print_timings:      sample time =   147.06 ms /   208 runs   (    0.71 ms per token,  1414.36 tokens per second)
# llama_print_timings: prompt eval time =   940.71 ms /    18 tokens (   52.26 ms per token,    19.13 tokens per second)
# llama_print_timings:        eval time = 11213.48 ms /   207 runs   (   54.17 ms per token,    18.46 tokens per second)
# llama_print_timings:       total time = 12604.38 ms
# Llama.generate: prefix-match hit
#   4%|██▌                                                     | 5/112 [01:12<25:54, 14.53s/it]
# llama_print_timings:        load time =  6919.55 ms
# llama_print_timings:      sample time =   180.66 ms /   256 runs   (    0.71 ms per token,  1416.99 tokens per second)
# llama_print_timings: prompt eval time =  1704.29 ms /    35 tokens (   48.69 ms per token,    20.54 tokens per second)
# llama_print_timings:        eval time = 13405.22 ms /   255 runs   (   52.57 ms per token,    19.02 tokens per second)
# llama_print_timings:       total time = 15660.42 ms
# Llama.generate: prefix-match hit
#   5%|███                                                     | 6/112 [01:27<25:50, 14.63s/it]
# llama_print_timings:        load time =  6919.55 ms
# llama_print_timings:      sample time =   181.67 ms /   256 runs   (    0.71 ms per token,  1409.18 tokens per second)
# llama_print_timings: prompt eval time =  1015.48 ms /    21 tokens (   48.36 ms per token,    20.68 tokens per second)
# llama_print_timings:        eval time = 13260.17 ms /   255 runs   (   52.00 ms per token,    19.23 tokens per second)
# llama_print_timings:       total time = 14825.94 ms
# Llama.generate: prefix-match hit
#   6%|███▌                                                    | 7/112 [01:42<26:18, 15.03s/it]
# llama_print_timings:        load time =  6919.55 ms
# llama_print_timings:      sample time =   181.90 ms /   256 runs   (    0.71 ms per token,  1407.34 tokens per second)
# llama_print_timings: prompt eval time =  1890.10 ms /    39 tokens (   48.46 ms per token,    20.63 tokens per second)
# llama_print_timings:        eval time = 13410.96 ms /   255 runs   (   52.59 ms per token,    19.01 tokens per second)
# llama_print_timings:       total time = 15857.36 ms
# Llama.generate: prefix-match hit
#   7%|████                                                    | 8/112 [01:57<25:58, 14.98s/it]
# llama_print_timings:        load time =  6919.55 ms
# llama_print_timings:      sample time =   181.44 ms /   256 runs   (    0.71 ms per token,  1410.90 tokens per second)
# llama_print_timings: prompt eval time =   966.66 ms /    20 tokens (   48.33 ms per token,    20.69 tokens per second)
# llama_print_timings:        eval time = 13360.38 ms /   255 runs   (   52.39 ms per token,    19.09 tokens per second)
# llama_print_timings:       total time = 14878.58 ms
# Llama.generate: prefix-match hit
#   8%|████▌                                                   | 9/112 [01:59<18:19, 10.68s/it]
# llama_print_timings:        load time =  6919.55 ms
# llama_print_timings:      sample time =     1.40 ms /     2 runs   (    0.70 ms per token,  1427.55 tokens per second)
# llama_print_timings: prompt eval time =  1145.27 ms /    24 tokens (   47.72 ms per token,    20.96 tokens per second)
# llama_print_timings:        eval time =    49.83 ms /     1 runs   (   49.83 ms per token,    20.07 tokens per second)
# llama_print_timings:       total time =  1201.27 ms
# Llama.generate: prefix-match hit
#   9%|████▉                                                  | 10/112 [02:13<20:11, 11.88s/it]
# llama_print_timings:        load time =  6919.55 ms
# llama_print_timings:      sample time =   180.41 ms /   256 runs   (    0.70 ms per token,  1418.98 tokens per second)
# llama_print_timings: prompt eval time =   766.06 ms /    16 tokens (   47.88 ms per token,    20.89 tokens per second)
# llama_print_timings:        eval time = 13247.34 ms /   256 runs   (   51.75 ms per token,    19.32 tokens per second)
# llama_print_timings:       total time = 14561.99 ms
# Llama.generate: prefix-match hit
#  10%|█████▍                                                 | 11/112 [02:28<21:27, 12.75s/it]
# llama_print_timings:        load time =  6919.55 ms
# llama_print_timings:      sample time =   180.17 ms /   256 runs   (    0.70 ms per token,  1420.86 tokens per second)
# llama_print_timings: prompt eval time =   909.98 ms /    19 tokens (   47.89 ms per token,    20.88 tokens per second)
# llama_print_timings:        eval time = 13255.91 ms /   255 runs   (   51.98 ms per token,    19.24 tokens per second)
# llama_print_timings:       total time = 14715.35 ms
# Llama.generate: prefix-match hit
#  11%|█████▉                                                 | 12/112 [02:42<22:08, 13.28s/it]
# llama_print_timings:        load time =  6919.55 ms
# llama_print_timings:      sample time =   179.54 ms /   256 runs   (    0.70 ms per token,  1425.87 tokens per second)
# llama_print_timings: prompt eval time =   802.64 ms /    16 tokens (   50.17 ms per token,    19.93 tokens per second)
# llama_print_timings:        eval time = 13157.54 ms /   255 runs   (   51.60 ms per token,    19.38 tokens per second)
# llama_print_timings:       total time = 14505.69 ms
# Llama.generate: prefix-match hit
#  12%|██████▍                                                | 13/112 [02:57<22:35, 13.69s/it]
# llama_print_timings:        load time =  6919.55 ms
# llama_print_timings:      sample time =   180.91 ms /   256 runs   (    0.71 ms per token,  1415.03 tokens per second)
# llama_print_timings: prompt eval time =   910.99 ms /    19 tokens (   47.95 ms per token,    20.86 tokens per second)
# llama_print_timings:        eval time = 13170.55 ms /   255 runs   (   51.65 ms per token,    19.36 tokens per second)
# llama_print_timings:       total time = 14632.61 ms
# Llama.generate: prefix-match hit
#  12%|██████▉                                                | 14/112 [03:11<22:32, 13.80s/it]
# llama_print_timings:        load time =  6919.55 ms
# llama_print_timings:      sample time =   180.85 ms /   256 runs   (    0.71 ms per token,  1415.55 tokens per second)
# llama_print_timings: prompt eval time =   382.56 ms /     8 tokens (   47.82 ms per token,    20.91 tokens per second)
# llama_print_timings:        eval time = 13127.28 ms /   256 runs   (   51.28 ms per token,    19.50 tokens per second)
# llama_print_timings:       total time = 14057.62 ms
# Llama.generate: prefix-match hit
#  13%|███████▎                                               | 15/112 [03:26<23:05, 14.28s/it]
# llama_print_timings:        load time =  6919.55 ms
# llama_print_timings:      sample time =   180.42 ms /   256 runs   (    0.70 ms per token,  1418.93 tokens per second)
# llama_print_timings: prompt eval time =  1532.17 ms /    32 tokens (   47.88 ms per token,    20.89 tokens per second)
# llama_print_timings:        eval time = 13314.50 ms /   256 runs   (   52.01 ms per token,    19.23 tokens per second)
# llama_print_timings:       total time = 15400.39 ms
# Llama.generate: prefix-match hit
#  14%|███████▊                                               | 16/112 [03:42<23:17, 14.56s/it]
# llama_print_timings:        load time =  6919.55 ms
# llama_print_timings:      sample time =   180.59 ms /   256 runs   (    0.71 ms per token,  1417.57 tokens per second)
# llama_print_timings: prompt eval time =  1394.05 ms /    29 tokens (   48.07 ms per token,    20.80 tokens per second)
# llama_print_timings:        eval time = 13250.91 ms /   255 runs   (   51.96 ms per token,    19.24 tokens per second)
# llama_print_timings:       total time = 15197.93 ms
# Llama.generate: prefix-match hit
#  15%|████████▎                                              | 17/112 [03:45<17:32, 11.07s/it]
# llama_print_timings:        load time =  6919.55 ms
# llama_print_timings:      sample time =    27.61 ms /    39 runs   (    0.71 ms per token,  1412.63 tokens per second)
# llama_print_timings: prompt eval time =   949.99 ms /    19 tokens (   50.00 ms per token,    20.00 tokens per second)
# llama_print_timings:        eval time =  1933.51 ms /    38 runs   (   50.88 ms per token,    19.65 tokens per second)
# llama_print_timings:       total time =  2965.82 ms
# Llama.generate: prefix-match hit
#  16%|████████▊                                              | 18/112 [04:00<19:17, 12.31s/it]
# llama_print_timings:        load time =  6919.55 ms
# llama_print_timings:      sample time =   180.21 ms /   255 runs   (    0.71 ms per token,  1415.06 tokens per second)
# llama_print_timings: prompt eval time =  1414.45 ms /    29 tokens (   48.77 ms per token,    20.50 tokens per second)
# llama_print_timings:        eval time = 13215.81 ms /   254 runs   (   52.03 ms per token,    19.22 tokens per second)
# llama_print_timings:       total time = 15181.87 ms
# Llama.generate: prefix-match hit
#  17%|█████████▎                                             | 19/112 [04:15<20:16, 13.08s/it]
# llama_print_timings:        load time =  6919.55 ms
# llama_print_timings:      sample time =   181.64 ms /   256 runs   (    0.71 ms per token,  1409.35 tokens per second)
# llama_print_timings: prompt eval time =   805.57 ms /    16 tokens (   50.35 ms per token,    19.86 tokens per second)
# llama_print_timings:        eval time = 13497.10 ms /   256 runs   (   52.72 ms per token,    18.97 tokens per second)
# llama_print_timings:       total time = 14862.83 ms
# Llama.generate: prefix-match hit
#  18%|█████████▊                                             | 20/112 [04:29<20:39, 13.47s/it]
# llama_print_timings:        load time =  6919.55 ms
# llama_print_timings:      sample time =   181.97 ms /   256 runs   (    0.71 ms per token,  1406.83 tokens per second)
# llama_print_timings: prompt eval time =   332.95 ms /     7 tokens (   47.56 ms per token,    21.02 tokens per second)
# llama_print_timings:        eval time = 13508.60 ms /   255 runs   (   52.97 ms per token,    18.88 tokens per second)
# llama_print_timings:       total time = 14400.71 ms
# Llama.generate: prefix-match hit
#  19%|██████████▎                                            | 21/112 [04:44<21:15, 14.02s/it]
# llama_print_timings:        load time =  6919.55 ms
# llama_print_timings:      sample time =   183.03 ms /   256 runs   (    0.71 ms per token,  1398.72 tokens per second)
# llama_print_timings: prompt eval time =   481.99 ms /    10 tokens (   48.20 ms per token,    20.75 tokens per second)
# llama_print_timings:        eval time = 14236.18 ms /   255 runs   (   55.83 ms per token,    17.91 tokens per second)
# llama_print_timings:       total time = 15284.70 ms
# Llama.generate: prefix-match hit
#  20%|██████████▊                                            | 22/112 [04:45<14:53,  9.93s/it]
# llama_print_timings:        load time =  6919.55 ms
# llama_print_timings:      sample time =     0.73 ms /     1 runs   (    0.73 ms per token,  1360.54 tokens per second)
# llama_print_timings: prompt eval time =   381.78 ms /     8 tokens (   47.72 ms per token,    20.95 tokens per second)
# llama_print_timings:        eval time =     0.00 ms /     1 runs   (    0.00 ms per token,      inf tokens per second)
# llama_print_timings:       total time =   382.94 ms
# Llama.generate: prefix-match hit
#  21%|███████████▎                                           | 23/112 [04:59<16:50, 11.36s/it]
# llama_print_timings:        load time =  6919.55 ms
# llama_print_timings:      sample time =   180.79 ms /   256 runs   (    0.71 ms per token,  1416.01 tokens per second)
# llama_print_timings: prompt eval time =   910.18 ms /    19 tokens (   47.90 ms per token,    20.87 tokens per second)
# llama_print_timings:        eval time = 13226.99 ms /   255 runs   (   51.87 ms per token,    19.28 tokens per second)
# llama_print_timings:       total time = 14691.15 ms
# Llama.generate: prefix-match hit
#  21%|███████████▊                                           | 24/112 [05:15<18:21, 12.51s/it]
# llama_print_timings:        load time =  6919.55 ms
# llama_print_timings:      sample time =   181.28 ms /   256 runs   (    0.71 ms per token,  1412.20 tokens per second)
# llama_print_timings: prompt eval time =  1393.02 ms /    29 tokens (   48.04 ms per token,    20.82 tokens per second)
# llama_print_timings:        eval time = 13206.23 ms /   255 runs   (   51.79 ms per token,    19.31 tokens per second)
# llama_print_timings:       total time = 15210.49 ms
# Llama.generate: prefix-match hit
#  22%|████████████▎                                          | 25/112 [05:29<18:54, 13.04s/it]
# llama_print_timings:        load time =  6919.55 ms
# llama_print_timings:      sample time =   180.83 ms /   256 runs   (    0.71 ms per token,  1415.71 tokens per second)
# llama_print_timings: prompt eval time =   529.57 ms /    11 tokens (   48.14 ms per token,    20.77 tokens per second)
# llama_print_timings:        eval time = 13176.73 ms /   255 runs   (   51.67 ms per token,    19.35 tokens per second)
# llama_print_timings:       total time = 14256.30 ms
# Llama.generate: prefix-match hit
#  23%|████████████▊                                          | 26/112 [05:43<19:16, 13.44s/it]
# llama_print_timings:        load time =  6919.55 ms
# llama_print_timings:      sample time =   180.47 ms /   256 runs   (    0.70 ms per token,  1418.51 tokens per second)
# llama_print_timings: prompt eval time =   669.52 ms /    14 tokens (   47.82 ms per token,    20.91 tokens per second)
# llama_print_timings:        eval time = 13172.60 ms /   255 runs   (   51.66 ms per token,    19.36 tokens per second)
# llama_print_timings:       total time = 14391.97 ms
# Llama.generate: prefix-match hit
#  24%|█████████████▎                                         | 27/112 [05:46<14:24, 10.17s/it]
# llama_print_timings:        load time =  6919.55 ms
# llama_print_timings:      sample time =    26.68 ms /    38 runs   (    0.70 ms per token,  1424.34 tokens per second)
# llama_print_timings: prompt eval time =   620.41 ms /    13 tokens (   47.72 ms per token,    20.95 tokens per second)
# llama_print_timings:        eval time =  1836.02 ms /    37 runs   (   49.62 ms per token,    20.15 tokens per second)
# llama_print_timings:       total time =  2534.48 ms
# Llama.generate: prefix-match hit
#  25%|█████████████▊                                         | 28/112 [06:00<15:57, 11.40s/it]
# llama_print_timings:        load time =  6919.55 ms
# llama_print_timings:      sample time =   181.25 ms /   256 runs   (    0.71 ms per token,  1412.44 tokens per second)
# llama_print_timings: prompt eval time =   385.69 ms /     8 tokens (   48.21 ms per token,    20.74 tokens per second)
# llama_print_timings:        eval time = 13331.62 ms /   255 runs   (   52.28 ms per token,    19.13 tokens per second)
# llama_print_timings:       total time = 14271.73 ms
# Llama.generate: prefix-match hit
#  26%|██████████████▏                                        | 29/112 [06:15<17:05, 12.35s/it]
# llama_print_timings:        load time =  6919.55 ms
# llama_print_timings:      sample time =   180.75 ms /   256 runs   (    0.71 ms per token,  1416.29 tokens per second)
# llama_print_timings: prompt eval time =   402.72 ms /     8 tokens (   50.34 ms per token,    19.86 tokens per second)
# llama_print_timings:        eval time = 13605.96 ms /   255 runs   (   53.36 ms per token,    18.74 tokens per second)
# llama_print_timings:       total time = 14567.43 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  6919.55 ms
#  27%|██████████████▋                                        | 30/112 [06:35<20:01, 14.65s/it]llama_print_timings:      sample time =   183.69 ms /   256 runs   (    0.72 ms per token,  1393.68 tokens per second)
# llama_print_timings: prompt eval time =   575.97 ms /    12 tokens (   48.00 ms per token,    20.83 tokens per second)
# llama_print_timings:        eval time = 18865.33 ms /   255 runs   (   73.98 ms per token,    13.52 tokens per second)
# llama_print_timings:       total time = 20022.19 ms
# Llama.generate: prefix-match hit
#  28%|███████████████▏                                       | 31/112 [06:59<23:39, 17.52s/it]
# llama_print_timings:        load time =  6919.55 ms
# llama_print_timings:      sample time =   184.75 ms /   256 runs   (    0.72 ms per token,  1385.66 tokens per second)
# llama_print_timings: prompt eval time =   405.36 ms /     6 tokens (   67.56 ms per token,    14.80 tokens per second)
# llama_print_timings:        eval time = 23206.28 ms /   255 runs   (   91.01 ms per token,    10.99 tokens per second)
# llama_print_timings:       total time = 24204.62 ms
# Llama.generate: prefix-match hit
#  29%|███████████████▋                                       | 32/112 [07:14<22:31, 16.89s/it]
# llama_print_timings:        load time =  6919.55 ms
# llama_print_timings:      sample time =   182.07 ms /   256 runs   (    0.71 ms per token,  1406.04 tokens per second)
# llama_print_timings: prompt eval time =  1345.66 ms /    28 tokens (   48.06 ms per token,    20.81 tokens per second)
# llama_print_timings:        eval time = 13512.90 ms /   255 runs   (   52.99 ms per token,    18.87 tokens per second)
# llama_print_timings:       total time = 15422.66 ms
# Llama.generate: prefix-match hit
#  29%|████████████████▏                                      | 33/112 [07:18<17:09, 13.03s/it]
# llama_print_timings:        load time =  6919.55 ms
# llama_print_timings:      sample time =    41.10 ms /    58 runs   (    0.71 ms per token,  1411.23 tokens per second)
# llama_print_timings: prompt eval time =   923.93 ms /    19 tokens (   48.63 ms per token,    20.56 tokens per second)
# llama_print_timings:        eval time =  2983.79 ms /    57 runs   (   52.35 ms per token,    19.10 tokens per second)
# llama_print_timings:       total time =  4030.65 ms
# Llama.generate: prefix-match hit
#  30%|████████████████▋                                      | 34/112 [07:33<17:33, 13.50s/it]
# llama_print_timings:        load time =  6919.55 ms
# llama_print_timings:      sample time =   181.72 ms /   256 runs   (    0.71 ms per token,  1408.72 tokens per second)
# llama_print_timings: prompt eval time =   538.45 ms /    11 tokens (   48.95 ms per token,    20.43 tokens per second)
# llama_print_timings:        eval time = 13492.35 ms /   255 runs   (   52.91 ms per token,    18.90 tokens per second)
# llama_print_timings:       total time = 14592.20 ms
# Llama.generate: prefix-match hit
#  31%|█████████████████▏                                     | 35/112 [07:47<17:38, 13.74s/it]
# llama_print_timings:        load time =  6919.55 ms
# llama_print_timings:      sample time =   180.62 ms /   256 runs   (    0.71 ms per token,  1417.34 tokens per second)
# llama_print_timings: prompt eval time =   623.43 ms /    13 tokens (   47.96 ms per token,    20.85 tokens per second)
# llama_print_timings:        eval time = 13133.63 ms /   255 runs   (   51.50 ms per token,    19.42 tokens per second)
# llama_print_timings:       total time = 14310.40 ms
# Llama.generate: prefix-match hit
#  32%|█████████████████▋                                     | 36/112 [08:03<18:18, 14.45s/it]
# llama_print_timings:        load time =  6919.55 ms
# llama_print_timings:      sample time =   179.72 ms /   256 runs   (    0.70 ms per token,  1424.43 tokens per second)
# llama_print_timings: prompt eval time =  2306.84 ms /    48 tokens (   48.06 ms per token,    20.81 tokens per second)
# llama_print_timings:        eval time = 13228.64 ms /   255 runs   (   51.88 ms per token,    19.28 tokens per second)
# llama_print_timings:       total time = 16090.19 ms
# Llama.generate: prefix-match hit
#  33%|██████████████████▏                                    | 37/112 [08:21<19:13, 15.39s/it]
# llama_print_timings:        load time =  6919.55 ms
# llama_print_timings:      sample time =   179.59 ms /   256 runs   (    0.70 ms per token,  1425.50 tokens per second)
# llama_print_timings: prompt eval time =  3670.41 ms /    76 tokens (   48.29 ms per token,    20.71 tokens per second)
# llama_print_timings:        eval time = 13338.87 ms /   255 runs   (   52.31 ms per token,    19.12 tokens per second)
# llama_print_timings:       total time = 17569.42 ms
# Llama.generate: prefix-match hit
#  34%|██████████████████▋                                    | 38/112 [08:38<19:37, 15.92s/it]
# llama_print_timings:        load time =  6919.55 ms
# llama_print_timings:      sample time =   179.91 ms /   256 runs   (    0.70 ms per token,  1422.97 tokens per second)
# llama_print_timings: prompt eval time =  3313.41 ms /    69 tokens (   48.02 ms per token,    20.82 tokens per second)
# llama_print_timings:        eval time = 13290.58 ms /   255 runs   (   52.12 ms per token,    19.19 tokens per second)
# llama_print_timings:       total time = 17161.29 ms
# Llama.generate: prefix-match hit
#  35%|███████████████████▏                                   | 39/112 [08:57<20:25, 16.79s/it]
# llama_print_timings:        load time =  6919.55 ms
# llama_print_timings:      sample time =   179.89 ms /   256 runs   (    0.70 ms per token,  1423.09 tokens per second)
# llama_print_timings: prompt eval time =  4817.27 ms /   100 tokens (   48.17 ms per token,    20.76 tokens per second)
# llama_print_timings:        eval time = 13431.17 ms /   255 runs   (   52.67 ms per token,    18.99 tokens per second)
# llama_print_timings:       total time = 18811.68 ms
# Llama.generate: prefix-match hit
#  36%|███████████████████▋                                   | 40/112 [09:14<20:16, 16.89s/it]
# llama_print_timings:        load time =  6919.55 ms
# llama_print_timings:      sample time =   179.26 ms /   256 runs   (    0.70 ms per token,  1428.10 tokens per second)
# llama_print_timings: prompt eval time =  3318.07 ms /    69 tokens (   48.09 ms per token,    20.80 tokens per second)
# llama_print_timings:        eval time = 13266.84 ms /   255 runs   (   52.03 ms per token,    19.22 tokens per second)
# llama_print_timings:       total time = 17141.30 ms
# Llama.generate: prefix-match hit
#  37%|████████████████████▏                                  | 41/112 [09:31<20:10, 17.05s/it]
# llama_print_timings:        load time =  6919.55 ms
# llama_print_timings:      sample time =   179.46 ms /   256 runs   (    0.70 ms per token,  1426.53 tokens per second)
# llama_print_timings: prompt eval time =  3456.66 ms /    72 tokens (   48.01 ms per token,    20.83 tokens per second)
# llama_print_timings:        eval time = 13391.32 ms /   255 runs   (   52.51 ms per token,    19.04 tokens per second)
# llama_print_timings:       total time = 17407.10 ms
# Llama.generate: prefix-match hit
#  38%|████████████████████▋                                  | 42/112 [09:40<16:54, 14.49s/it]
# llama_print_timings:        load time =  6919.55 ms
# llama_print_timings:      sample time =    75.03 ms /   107 runs   (    0.70 ms per token,  1426.13 tokens per second)
# llama_print_timings: prompt eval time =  2900.77 ms /    60 tokens (   48.35 ms per token,    20.68 tokens per second)
# llama_print_timings:        eval time =  5401.49 ms /   106 runs   (   50.96 ms per token,    19.62 tokens per second)
# llama_print_timings:       total time =  8531.69 ms
# Llama.generate: prefix-match hit
#  38%|█████████████████████                                  | 43/112 [09:57<17:42, 15.40s/it]
# llama_print_timings:        load time =  6919.55 ms
# llama_print_timings:      sample time =   179.56 ms /   256 runs   (    0.70 ms per token,  1425.74 tokens per second)
# llama_print_timings: prompt eval time =  3599.39 ms /    75 tokens (   47.99 ms per token,    20.84 tokens per second)
# llama_print_timings:        eval time = 13342.61 ms /   255 runs   (   52.32 ms per token,    19.11 tokens per second)
# llama_print_timings:       total time = 17502.48 ms
# Llama.generate: prefix-match hit
#  39%|█████████████████████▌                                 | 44/112 [10:11<16:51, 14.88s/it]
# llama_print_timings:        load time =  6919.55 ms
# llama_print_timings:      sample time =   133.04 ms /   190 runs   (    0.70 ms per token,  1428.11 tokens per second)
# llama_print_timings: prompt eval time =  3445.53 ms /    72 tokens (   47.85 ms per token,    20.90 tokens per second)
# llama_print_timings:        eval time =  9816.50 ms /   190 runs   (   51.67 ms per token,    19.36 tokens per second)
# llama_print_timings:       total time = 13673.28 ms
# Llama.generate: prefix-match hit
#  40%|██████████████████████                                 | 45/112 [10:24<16:03, 14.38s/it]
# llama_print_timings:        load time =  6919.55 ms
# llama_print_timings:      sample time =   125.04 ms /   178 runs   (    0.70 ms per token,  1423.59 tokens per second)
# llama_print_timings: prompt eval time =  3547.55 ms /    74 tokens (   47.94 ms per token,    20.86 tokens per second)
# llama_print_timings:        eval time =  9293.23 ms /   177 runs   (   52.50 ms per token,    19.05 tokens per second)
# llama_print_timings:       total time = 13226.51 ms
# Llama.generate: prefix-match hit
#  41%|██████████████████████▌                                | 46/112 [10:48<18:47, 17.08s/it]
# llama_print_timings:        load time =  6919.55 ms
# llama_print_timings:      sample time =   180.25 ms /   256 runs   (    0.70 ms per token,  1420.27 tokens per second)
# llama_print_timings: prompt eval time =  9159.04 ms /   110 tokens (   83.26 ms per token,    12.01 tokens per second)
# llama_print_timings:        eval time = 13627.86 ms /   255 runs   (   53.44 ms per token,    18.71 tokens per second)
# llama_print_timings:       total time = 23360.31 ms
# Llama.generate: prefix-match hit
#  42%|███████████████████████                                | 47/112 [10:52<14:24, 13.30s/it]
# llama_print_timings:        load time =  6919.55 ms
# llama_print_timings:      sample time =     1.40 ms /     2 runs   (    0.70 ms per token,  1431.64 tokens per second)
# llama_print_timings: prompt eval time =  4415.94 ms /    92 tokens (   48.00 ms per token,    20.83 tokens per second)
# llama_print_timings:        eval time =    50.80 ms /     1 runs   (   50.80 ms per token,    19.68 tokens per second)
# llama_print_timings:       total time =  4482.68 ms
# Llama.generate: prefix-match hit
#  43%|███████████████████████▌                               | 48/112 [11:12<16:24, 15.38s/it]
# llama_print_timings:        load time =  6919.55 ms
# llama_print_timings:      sample time =   181.91 ms /   256 runs   (    0.71 ms per token,  1407.32 tokens per second)
# llama_print_timings: prompt eval time =  6110.14 ms /   126 tokens (   48.49 ms per token,    20.62 tokens per second)
# llama_print_timings:        eval time = 13557.00 ms /   255 runs   (   53.16 ms per token,    18.81 tokens per second)
# llama_print_timings:       total time = 20241.13 ms
# Llama.generate: prefix-match hit
#  44%|████████████████████████                               | 49/112 [11:32<17:19, 16.51s/it]
# llama_print_timings:        load time =  6919.55 ms
# llama_print_timings:      sample time =   180.51 ms /   256 runs   (    0.71 ms per token,  1418.20 tokens per second)
# llama_print_timings: prompt eval time =  4989.27 ms /   104 tokens (   47.97 ms per token,    20.84 tokens per second)
# llama_print_timings:        eval time = 13570.10 ms /   256 runs   (   53.01 ms per token,    18.87 tokens per second)
# llama_print_timings:       total time = 19128.89 ms
# Llama.generate: prefix-match hit
#  45%|████████████████████████▌                              | 50/112 [11:50<17:41, 17.11s/it]
# llama_print_timings:        load time =  6919.55 ms
# llama_print_timings:      sample time =   179.47 ms /   256 runs   (    0.70 ms per token,  1426.41 tokens per second)
# llama_print_timings: prompt eval time =  4564.76 ms /    95 tokens (   48.05 ms per token,    20.81 tokens per second)
# llama_print_timings:        eval time = 13399.56 ms /   255 runs   (   52.55 ms per token,    19.03 tokens per second)
# llama_print_timings:       total time = 18527.42 ms
# Llama.generate: prefix-match hit
#  46%|█████████████████████████                              | 51/112 [12:06<16:57, 16.68s/it]
# llama_print_timings:        load time =  6919.55 ms
# llama_print_timings:      sample time =   179.47 ms /   256 runs   (    0.70 ms per token,  1426.38 tokens per second)
# llama_print_timings: prompt eval time =  1910.75 ms /    40 tokens (   47.77 ms per token,    20.93 tokens per second)
# llama_print_timings:        eval time = 13186.66 ms /   256 runs   (   51.51 ms per token,    19.41 tokens per second)
# llama_print_timings:       total time = 15651.86 ms
# Llama.generate: prefix-match hit
#  46%|█████████████████████████▌                             | 52/112 [12:23<16:54, 16.91s/it]
# llama_print_timings:        load time =  6919.55 ms
# llama_print_timings:      sample time =   179.44 ms /   256 runs   (    0.70 ms per token,  1426.63 tokens per second)
# llama_print_timings: prompt eval time =  3598.56 ms /    75 tokens (   47.98 ms per token,    20.84 tokens per second)
# llama_print_timings:        eval time = 13305.56 ms /   255 runs   (   52.18 ms per token,    19.16 tokens per second)
# llama_print_timings:       total time = 17464.11 ms
# Llama.generate: prefix-match hit
#  47%|██████████████████████████                             | 53/112 [12:41<16:59, 17.28s/it]
# llama_print_timings:        load time =  6919.55 ms
# llama_print_timings:      sample time =   180.44 ms /   256 runs   (    0.70 ms per token,  1418.79 tokens per second)
# llama_print_timings: prompt eval time =  4072.10 ms /    85 tokens (   47.91 ms per token,    20.87 tokens per second)
# llama_print_timings:        eval time = 13503.56 ms /   255 runs   (   52.96 ms per token,    18.88 tokens per second)
# llama_print_timings:       total time = 18144.88 ms
# Llama.generate: prefix-match hit
#  48%|██████████████████████████▌                            | 54/112 [12:59<16:51, 17.44s/it]
# llama_print_timings:        load time =  6919.55 ms
# llama_print_timings:      sample time =   180.95 ms /   256 runs   (    0.71 ms per token,  1414.76 tokens per second)
# llama_print_timings: prompt eval time =  3455.39 ms /    72 tokens (   47.99 ms per token,    20.84 tokens per second)
# llama_print_timings:        eval time = 13786.04 ms /   255 runs   (   54.06 ms per token,    18.50 tokens per second)
# llama_print_timings:       total time = 17813.50 ms
# Llama.generate: prefix-match hit
#  49%|███████████████████████████                            | 55/112 [13:16<16:20, 17.21s/it]
# llama_print_timings:        load time =  6919.55 ms
# llama_print_timings:      sample time =   181.24 ms /   256 runs   (    0.71 ms per token,  1412.47 tokens per second)
# llama_print_timings: prompt eval time =  2455.37 ms /    51 tokens (   48.14 ms per token,    20.77 tokens per second)
# llama_print_timings:        eval time = 13633.84 ms /   255 runs   (   53.47 ms per token,    18.70 tokens per second)
# llama_print_timings:       total time = 16659.54 ms
# Llama.generate: prefix-match hit
#  50%|███████████████████████████▌                           | 56/112 [13:24<13:25, 14.38s/it]
# llama_print_timings:        load time =  6919.55 ms
# llama_print_timings:      sample time =    64.51 ms /    90 runs   (    0.72 ms per token,  1395.09 tokens per second)
# llama_print_timings: prompt eval time =  2788.74 ms /    55 tokens (   50.70 ms per token,    19.72 tokens per second)
# llama_print_timings:        eval time =  4785.49 ms /    89 runs   (   53.77 ms per token,    18.60 tokens per second)
# llama_print_timings:       total time =  7773.83 ms
# Llama.generate: prefix-match hit
#  51%|███████████████████████████▉                           | 57/112 [13:42<14:16, 15.57s/it]
# llama_print_timings:        load time =  6919.55 ms
# llama_print_timings:      sample time =   181.81 ms /   256 runs   (    0.71 ms per token,  1408.09 tokens per second)
# llama_print_timings: prompt eval time =  3802.07 ms /    78 tokens (   48.74 ms per token,    20.52 tokens per second)
# llama_print_timings:        eval time = 13972.63 ms /   255 runs   (   54.79 ms per token,    18.25 tokens per second)
# llama_print_timings:       total time = 18350.84 ms
# Llama.generate: prefix-match hit
#  52%|████████████████████████████▍                          | 58/112 [13:58<14:08, 15.72s/it]
# llama_print_timings:        load time =  6919.55 ms
# llama_print_timings:      sample time =    89.55 ms /   127 runs   (    0.71 ms per token,  1418.23 tokens per second)
# llama_print_timings: prompt eval time =  9041.40 ms /   187 tokens (   48.35 ms per token,    20.68 tokens per second)
# llama_print_timings:        eval time =  6728.41 ms /   126 runs   (   53.40 ms per token,    18.73 tokens per second)
# llama_print_timings:       total time = 16065.67 ms
# Llama.generate: prefix-match hit
#  53%|████████████████████████████▉                          | 59/112 [14:23<16:27, 18.62s/it]
# llama_print_timings:        load time =  6919.55 ms
# llama_print_timings:      sample time =   169.35 ms /   240 runs   (    0.71 ms per token,  1417.17 tokens per second)
# llama_print_timings: prompt eval time = 11507.97 ms /   231 tokens (   49.82 ms per token,    20.07 tokens per second)
# llama_print_timings:        eval time = 13333.92 ms /   239 runs   (   55.79 ms per token,    17.92 tokens per second)
# llama_print_timings:       total time = 25399.90 ms
# Llama.generate: prefix-match hit
#  54%|█████████████████████████████▍                         | 60/112 [14:50<18:17, 21.11s/it]
# llama_print_timings:        load time =  6919.55 ms
# llama_print_timings:      sample time =   180.54 ms /   256 runs   (    0.71 ms per token,  1417.97 tokens per second)
# llama_print_timings: prompt eval time = 12112.56 ms /   250 tokens (   48.45 ms per token,    20.64 tokens per second)
# llama_print_timings:        eval time = 14200.70 ms /   255 runs   (   55.69 ms per token,    17.96 tokens per second)
# llama_print_timings:       total time = 26907.15 ms
# Llama.generate: prefix-match hit
#  54%|█████████████████████████████▉                         | 61/112 [15:02<15:24, 18.13s/it]
# llama_print_timings:        load time =  6919.55 ms
# llama_print_timings:      sample time =    48.53 ms /    69 runs   (    0.70 ms per token,  1421.77 tokens per second)
# llama_print_timings: prompt eval time =  7486.47 ms /   155 tokens (   48.30 ms per token,    20.70 tokens per second)
# llama_print_timings:        eval time =  3532.10 ms /    68 runs   (   51.94 ms per token,    19.25 tokens per second)
# llama_print_timings:       total time = 11183.65 ms
# Llama.generate: prefix-match hit
#  55%|██████████████████████████████▍                        | 62/112 [15:12<13:04, 15.70s/it]
# llama_print_timings:        load time =  6919.55 ms
# llama_print_timings:      sample time =    24.55 ms /    35 runs   (    0.70 ms per token,  1425.37 tokens per second)
# llama_print_timings: prompt eval time =  8149.80 ms /   168 tokens (   48.51 ms per token,    20.61 tokens per second)
# llama_print_timings:        eval time =  1769.58 ms /    34 runs   (   52.05 ms per token,    19.21 tokens per second)
# llama_print_timings:       total time = 10014.40 ms
# Llama.generate: prefix-match hit
#
#  56%|██████████████████████████████▉                        | 63/112 [15:38<15:28, 18.95s/it]llama_print_timings:        load time =  6919.55 ms
# llama_print_timings:      sample time =   180.53 ms /   256 runs   (    0.71 ms per token,  1418.05 tokens per second)
# llama_print_timings: prompt eval time = 11782.15 ms /   243 tokens (   48.49 ms per token,    20.62 tokens per second)
# llama_print_timings:        eval time = 14160.03 ms /   255 runs   (   55.53 ms per token,    18.01 tokens per second)
# llama_print_timings:       total time = 26533.45 ms
# Llama.generate: prefix-match hit
#  57%|███████████████████████████████▍                       | 64/112 [15:59<15:39, 19.58s/it]
# llama_print_timings:        load time =  6919.55 ms
# llama_print_timings:      sample time =   179.52 ms /   256 runs   (    0.70 ms per token,  1426.06 tokens per second)
# llama_print_timings: prompt eval time =  6903.48 ms /   143 tokens (   48.28 ms per token,    20.71 tokens per second)
# llama_print_timings:        eval time = 13564.27 ms /   255 runs   (   53.19 ms per token,    18.80 tokens per second)
# llama_print_timings:       total time = 21039.64 ms
# Llama.generate: prefix-match hit
#  58%|███████████████████████████████▉                       | 65/112 [16:24<16:28, 21.03s/it]
# llama_print_timings:        load time =  6919.55 ms
# llama_print_timings:      sample time =   181.03 ms /   256 runs   (    0.71 ms per token,  1414.16 tokens per second)
# llama_print_timings: prompt eval time =  9571.72 ms /   198 tokens (   48.34 ms per token,    20.69 tokens per second)
# llama_print_timings:        eval time = 14256.81 ms /   255 runs   (   55.91 ms per token,    17.89 tokens per second)
# llama_print_timings:       total time = 24418.40 ms
# Llama.generate: prefix-match hit
#  59%|████████████████████████████████▍                      | 66/112 [16:34<13:43, 17.89s/it]
# llama_print_timings:        load time =  6919.55 ms
# llama_print_timings:      sample time =    41.10 ms /    58 runs   (    0.71 ms per token,  1411.12 tokens per second)
# llama_print_timings: prompt eval time =  7363.68 ms /   152 tokens (   48.45 ms per token,    20.64 tokens per second)
# llama_print_timings:        eval time =  3063.68 ms /    57 runs   (   53.75 ms per token,    18.61 tokens per second)
# llama_print_timings:       total time = 10571.08 ms
# Llama.generate: prefix-match hit
#  60%|████████████████████████████████▉                      | 67/112 [16:51<13:06, 17.48s/it]
# llama_print_timings:        load time =  6919.55 ms
# llama_print_timings:      sample time =     1.40 ms /     2 runs   (    0.70 ms per token,  1431.64 tokens per second)
# llama_print_timings: prompt eval time = 16347.41 ms /   336 tokens (   48.65 ms per token,    20.55 tokens per second)
# llama_print_timings:        eval time =   108.68 ms /     2 runs   (   54.34 ms per token,    18.40 tokens per second)
# llama_print_timings:       total time = 16507.72 ms
# Llama.generate: prefix-match hit
#  61%|█████████████████████████████████▍                     | 68/112 [17:15<14:20, 19.57s/it]
# llama_print_timings:        load time =  6919.55 ms
# llama_print_timings:      sample time =   180.07 ms /   256 runs   (    0.70 ms per token,  1421.65 tokens per second)
# llama_print_timings: prompt eval time =  9824.25 ms /   202 tokens (   48.63 ms per token,    20.56 tokens per second)
# llama_print_timings:        eval time = 14028.26 ms /   255 runs   (   55.01 ms per token,    18.18 tokens per second)
# llama_print_timings:       total time = 24440.04 ms
# Llama.generate: prefix-match hit
#  62%|█████████████████████████████████▉                     | 69/112 [17:44<15:57, 22.27s/it]
# llama_print_timings:        load time =  6919.55 ms
# llama_print_timings:      sample time =   179.33 ms /   256 runs   (    0.70 ms per token,  1427.55 tokens per second)
# llama_print_timings: prompt eval time = 13730.82 ms /   283 tokens (   48.52 ms per token,    20.61 tokens per second)
# llama_print_timings:        eval time = 14241.84 ms /   255 runs   (   55.85 ms per token,    17.90 tokens per second)
# llama_print_timings:       total time = 28566.11 ms
# Llama.generate: prefix-match hit
#  62%|██████████████████████████████████▍                    | 70/112 [18:14<17:22, 24.82s/it]
# llama_print_timings:        load time =  6919.55 ms
# llama_print_timings:      sample time =   179.27 ms /   256 runs   (    0.70 ms per token,  1428.00 tokens per second)
# llama_print_timings: prompt eval time = 15784.72 ms /   325 tokens (   48.57 ms per token,    20.59 tokens per second)
# llama_print_timings:        eval time = 14391.29 ms /   255 runs   (   56.44 ms per token,    17.72 tokens per second)
# llama_print_timings:       total time = 30774.25 ms
# Llama.generate: prefix-match hit
#  63%|██████████████████████████████████▊                    | 71/112 [18:39<16:51, 24.66s/it]
# llama_print_timings:        load time =  6919.55 ms
# llama_print_timings:      sample time =   142.65 ms /   203 runs   (    0.70 ms per token,  1423.10 tokens per second)
# llama_print_timings: prompt eval time = 12740.01 ms /   263 tokens (   48.44 ms per token,    20.64 tokens per second)
# llama_print_timings:        eval time = 11085.88 ms /   202 runs   (   54.88 ms per token,    18.22 tokens per second)
# llama_print_timings:       total time = 24295.59 ms
# Llama.generate: prefix-match hit
#  64%|███████████████████████████████████▎                   | 72/112 [19:04<16:34, 24.87s/it]
# llama_print_timings:        load time =  6919.55 ms
# llama_print_timings:      sample time =   179.70 ms /   256 runs   (    0.70 ms per token,  1424.60 tokens per second)
# llama_print_timings: prompt eval time = 10798.67 ms /   223 tokens (   48.42 ms per token,    20.65 tokens per second)
# llama_print_timings:        eval time = 13950.97 ms /   255 runs   (   54.71 ms per token,    18.28 tokens per second)
# llama_print_timings:       total time = 25334.07 ms
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =  6919.55 ms
#  65%|███████████████████████████████████▊                   | 73/112 [19:30<16:22, 25.19s/it]llama_print_timings:      sample time =   180.47 ms /   256 runs   (    0.70 ms per token,  1418.56 tokens per second)
# llama_print_timings: prompt eval time = 11123.55 ms /   230 tokens (   48.36 ms per token,    20.68 tokens per second)
# llama_print_timings:        eval time = 14238.88 ms /   255 runs   (   55.84 ms per token,    17.91 tokens per second)
# llama_print_timings:       total time = 25951.57 ms
# Llama.generate: prefix-match hit
#  66%|████████████████████████████████████▎                  | 74/112 [20:38<24:01, 37.93s/it]
# llama_print_timings:        load time =  6919.55 ms
# llama_print_timings:      sample time =   179.37 ms /   256 runs   (    0.70 ms per token,  1427.19 tokens per second)
# llama_print_timings: prompt eval time = 53255.22 ms /   184 tokens (  289.43 ms per token,     3.46 tokens per second)
# llama_print_timings:        eval time = 13812.91 ms /   256 runs   (   53.96 ms per token,    18.53 tokens per second)
# llama_print_timings:       total time = 67652.03 ms
# Llama.generate: prefix-match hit
#  67%|████████████████████████████████████▊                  | 75/112 [21:01<20:36, 33.43s/it]
# llama_print_timings:        load time =  6919.55 ms
# llama_print_timings:      sample time =   181.45 ms /   256 runs   (    0.71 ms per token,  1410.83 tokens per second)
# llama_print_timings: prompt eval time =  8492.05 ms /   176 tokens (   48.25 ms per token,    20.73 tokens per second)
# llama_print_timings:        eval time = 13834.30 ms /   256 runs   (   54.04 ms per token,    18.50 tokens per second)
# llama_print_timings:       total time = 22910.97 ms
# Llama.generate: prefix-match hit
#  68%|█████████████████████████████████████▎                 | 76/112 [21:23<18:02, 30.06s/it]
# llama_print_timings:        load time =  6919.55 ms
# llama_print_timings:      sample time =   181.13 ms /   256 runs   (    0.71 ms per token,  1413.31 tokens per second)
# llama_print_timings: prompt eval time =  7895.75 ms /   164 tokens (   48.14 ms per token,    20.77 tokens per second)
# llama_print_timings:        eval time = 13720.89 ms /   255 runs   (   53.81 ms per token,    18.58 tokens per second)
# llama_print_timings:       total time = 22198.80 ms
# Llama.generate: prefix-match hit
#  69%|█████████████████████████████████████▊                 | 77/112 [21:48<16:43, 28.67s/it]
# llama_print_timings:        load time =  6919.55 ms
# llama_print_timings:      sample time =   179.80 ms /   256 runs   (    0.70 ms per token,  1423.78 tokens per second)
# llama_print_timings: prompt eval time = 10822.69 ms /   224 tokens (   48.32 ms per token,    20.70 tokens per second)
# llama_print_timings:        eval time = 14013.73 ms /   256 runs   (   54.74 ms per token,    18.27 tokens per second)
# llama_print_timings:       total time = 25423.91 ms
# Llama.generate: prefix-match hit
#  70%|██████████████████████████████████████▎                | 78/112 [22:11<15:19, 27.05s/it]
# llama_print_timings:        load time =  6919.55 ms
# llama_print_timings:      sample time =   179.60 ms /   256 runs   (    0.70 ms per token,  1425.40 tokens per second)
# llama_print_timings: prompt eval time =  8890.67 ms /   184 tokens (   48.32 ms per token,    20.70 tokens per second)
# llama_print_timings:        eval time = 13805.30 ms /   255 runs   (   54.14 ms per token,    18.47 tokens per second)
# llama_print_timings:       total time = 23276.63 ms
# Llama.generate: prefix-match hit
#  71%|██████████████████████████████████████▊                | 79/112 [22:33<13:58, 25.40s/it]
# llama_print_timings:        load time =  6919.55 ms
# llama_print_timings:      sample time =   179.44 ms /   256 runs   (    0.70 ms per token,  1426.64 tokens per second)
# llama_print_timings: prompt eval time =  7330.99 ms /   152 tokens (   48.23 ms per token,    20.73 tokens per second)
# llama_print_timings:        eval time = 13635.74 ms /   255 runs   (   53.47 ms per token,    18.70 tokens per second)
# llama_print_timings:       total time = 21540.52 ms
# Llama.generate: prefix-match hit
#  71%|███████████████████████████████████████▎               | 80/112 [23:01<13:56, 26.14s/it]
# llama_print_timings:        load time =  6919.55 ms
# llama_print_timings:      sample time =   179.38 ms /   256 runs   (    0.70 ms per token,  1427.12 tokens per second)
# llama_print_timings: prompt eval time = 13133.31 ms /   270 tokens (   48.64 ms per token,    20.56 tokens per second)
# llama_print_timings:        eval time = 14147.26 ms /   255 runs   (   55.48 ms per token,    18.02 tokens per second)
# llama_print_timings:       total time = 27873.43 ms
# Llama.generate: prefix-match hit
#  72%|███████████████████████████████████████▊               | 81/112 [23:23<12:53, 24.95s/it]
# llama_print_timings:        load time =  6919.55 ms
# llama_print_timings:      sample time =   131.83 ms /   188 runs   (    0.70 ms per token,  1426.05 tokens per second)
# llama_print_timings: prompt eval time = 11599.55 ms /   240 tokens (   48.33 ms per token,    20.69 tokens per second)
# llama_print_timings:        eval time = 10138.75 ms /   187 runs   (   54.22 ms per token,    18.44 tokens per second)
# llama_print_timings:       total time = 22173.19 ms
# Llama.generate: prefix-match hit
#  73%|████████████████████████████████████████▎              | 82/112 [23:33<10:09, 20.32s/it]
# llama_print_timings:        load time =  6919.55 ms
# ...
# Llama.generate: prefix-match hit
#  77%|██████████████████████████████████████████▏            | 86/112 [25:18<10:51, 25.05s/it]
# llama_print_timings:        load time =  6919.55 ms
# llama_print_timings:      sample time =   180.12 ms /   256 runs   (    0.70 ms per token,  1421.24 tokens per second)
# llama_print_timings: prompt eval time = 10045.54 ms /   208 tokens (   48.30 ms per token,    20.71 tokens per second)
# llama_print_timings:        eval time = 13884.33 ms /   256 runs   (   54.24 ms per token,    18.44 tokens per second)
# llama_print_timings:       total time = 24515.84 ms
# Llama.generate: prefix-match hit
#  78%|██████████████████████████████████████████▋            | 87/112 [25:44<10:33, 25.35s/it]
# llama_print_timings:        load time =  6919.55 ms
# llama_print_timings:      sample time =   179.08 ms /   256 runs   (    0.70 ms per token,  1429.53 tokens per second)
# llama_print_timings: prompt eval time = 11496.58 ms /   238 tokens (   48.30 ms per token,    20.70 tokens per second)
# llama_print_timings:        eval time = 13963.74 ms /   255 runs   (   54.76 ms per token,    18.26 tokens per second)
# llama_print_timings:       total time = 26046.25 ms
# Llama.generate: prefix-match hit
#  79%|███████████████████████████████████████████▏           | 88/112 [25:59<08:50, 22.09s/it]
# llama_print_timings:        load time =  6919.55 ms
# llama_print_timings:      sample time =    93.12 ms /   133 runs   (    0.70 ms per token,  1428.19 tokens per second)
# llama_print_timings: prompt eval time =  7293.99 ms /   151 tokens (   48.30 ms per token,    20.70 tokens per second)
# llama_print_timings:        eval time =  6875.92 ms /   132 runs   (   52.09 ms per token,    19.20 tokens per second)
# llama_print_timings:       total time = 14470.28 ms
# Llama.generate: prefix-match hit
#  79%|███████████████████████████████████████████▋           | 89/112 [26:24<08:47, 22.93s/it]
# llama_print_timings:        load time =  6919.55 ms
# llama_print_timings:      sample time =   180.08 ms /   256 runs   (    0.70 ms per token,  1421.60 tokens per second)
# llama_print_timings: prompt eval time = 10191.43 ms /   211 tokens (   48.30 ms per token,    20.70 tokens per second)
# llama_print_timings:        eval time = 14111.04 ms /   255 runs   (   55.34 ms per token,    18.07 tokens per second)
# llama_print_timings:       total time = 24892.22 ms
# Llama.generate: prefix-match hit
#  80%|████████████████████████████████████████████▏          | 90/112 [27:03<10:09, 27.71s/it]
# llama_print_timings:        load time =  6919.55 ms
# llama_print_timings:      sample time =   180.56 ms /   256 runs   (    0.71 ms per token,  1417.83 tokens per second)
# llama_print_timings: prompt eval time = 23061.53 ms /   471 tokens (   48.96 ms per token,    20.42 tokens per second)
# llama_print_timings:        eval time = 15156.53 ms /   255 runs   (   59.44 ms per token,    16.82 tokens per second)
# llama_print_timings:       total time = 38852.25 ms
# Llama.generate: prefix-match hit
#  81%|████████████████████████████████████████████▋          | 91/112 [27:31<09:48, 28.03s/it]
# llama_print_timings:        load time =  6919.55 ms
# llama_print_timings:      sample time =   136.79 ms /   194 runs   (    0.71 ms per token,  1418.19 tokens per second)
# llama_print_timings: prompt eval time = 17251.85 ms /   352 tokens (   49.01 ms per token,    20.40 tokens per second)
# llama_print_timings:        eval time = 11064.75 ms /   193 runs   (   57.33 ms per token,    17.44 tokens per second)
# llama_print_timings:       total time = 28787.43 ms
# Llama.generate: prefix-match hit
#  82%|█████████████████████████████████████████████▏         | 92/112 [27:38<07:14, 21.73s/it]
# llama_print_timings:        load time =  6919.55 ms
# llama_print_timings:      sample time =     0.71 ms /     1 runs   (    0.71 ms per token,  1402.52 tokens per second)
# llama_print_timings: prompt eval time =  6934.34 ms /   144 tokens (   48.16 ms per token,    20.77 tokens per second)
# llama_print_timings:        eval time =    50.85 ms /     1 runs   (   50.85 ms per token,    19.67 tokens per second)
# llama_print_timings:       total time =  7007.59 ms
# Llama.generate: prefix-match hit
#  83%|█████████████████████████████████████████████▋         | 93/112 [27:59<06:44, 21.27s/it]
# llama_print_timings:        load time =  6919.55 ms
# llama_print_timings:      sample time =    68.17 ms /    97 runs   (    0.70 ms per token,  1422.93 tokens per second)
# llama_print_timings: prompt eval time = 14704.76 ms /   302 tokens (   48.69 ms per token,    20.54 tokens per second)
# llama_print_timings:        eval time =  5255.43 ms /    96 runs   (   54.74 ms per token,    18.27 tokens per second)
# llama_print_timings:       total time = 20206.97 ms
# Llama.generate: prefix-match hit
#  84%|██████████████████████████████████████████████▏        | 94/112 [28:22<06:33, 21.87s/it]
# llama_print_timings:        load time =  6919.55 ms
# llama_print_timings:      sample time =   181.39 ms /   256 runs   (    0.71 ms per token,  1411.32 tokens per second)
# llama_print_timings: prompt eval time =  8664.96 ms /   179 tokens (   48.41 ms per token,    20.66 tokens per second)
# llama_print_timings:        eval time = 14016.86 ms /   255 runs   (   54.97 ms per token,    18.19 tokens per second)
# llama_print_timings:       total time = 23274.92 ms
# Llama.generate: prefix-match hit
#  85%|██████████████████████████████████████████████▋        | 95/112 [28:45<06:18, 22.27s/it]
# llama_print_timings:        load time =  6919.55 ms
# llama_print_timings:      sample time =   180.91 ms /   256 runs   (    0.71 ms per token,  1415.08 tokens per second)
# llama_print_timings: prompt eval time =  8760.77 ms /   180 tokens (   48.67 ms per token,    20.55 tokens per second)
# llama_print_timings:        eval time = 13837.61 ms /   255 runs   (   54.27 ms per token,    18.43 tokens per second)
# llama_print_timings:       total time = 23186.58 ms
# Llama.generate: prefix-match hit
#  86%|███████████████████████████████████████████████▏       | 96/112 [29:07<05:53, 22.11s/it]
# llama_print_timings:        load time =  6919.55 ms
# llama_print_timings:      sample time =   181.34 ms /   256 runs   (    0.71 ms per token,  1411.68 tokens per second)
# llama_print_timings: prompt eval time =  7259.10 ms /   150 tokens (   48.39 ms per token,    20.66 tokens per second)
# llama_print_timings:        eval time = 13904.67 ms /   255 runs   (   54.53 ms per token,    18.34 tokens per second)
# llama_print_timings:       total time = 21751.07 ms
# Llama.generate: prefix-match hit
#  87%|███████████████████████████████████████████████▋       | 97/112 [29:33<05:49, 23.29s/it]
# llama_print_timings:        load time =  6919.55 ms
# llama_print_timings:      sample time =   180.84 ms /   256 runs   (    0.71 ms per token,  1415.59 tokens per second)
# llama_print_timings: prompt eval time = 11183.04 ms /   228 tokens (   49.05 ms per token,    20.39 tokens per second)
# llama_print_timings:        eval time = 14237.02 ms /   255 runs   (   55.83 ms per token,    17.91 tokens per second)
# llama_print_timings:       total time = 26019.95 ms
# Llama.generate: prefix-match hit
#  88%|████████████████████████████████████████████████▏      | 98/112 [29:52<05:07, 22.00s/it]
# llama_print_timings:        load time =  6919.55 ms
# llama_print_timings:      sample time =    92.31 ms /   131 runs   (    0.70 ms per token,  1419.19 tokens per second)
# llama_print_timings: prompt eval time = 11670.03 ms /   239 tokens (   48.83 ms per token,    20.48 tokens per second)
# llama_print_timings:        eval time =  7009.01 ms /   130 runs   (   53.92 ms per token,    18.55 tokens per second)
# llama_print_timings:       total time = 18992.50 ms
# Llama.generate: prefix-match hit
#  88%|████████████████████████████████████████████████▌      | 99/112 [30:13<04:42, 21.74s/it]
# llama_print_timings:        load time =  6919.55 ms
# llama_print_timings:      sample time =   117.89 ms /   168 runs   (    0.70 ms per token,  1425.02 tokens per second)
# llama_print_timings: prompt eval time = 11580.34 ms /   238 tokens (   48.66 ms per token,    20.55 tokens per second)
# llama_print_timings:        eval time =  9148.42 ms /   167 runs   (   54.78 ms per token,    18.25 tokens per second)
# llama_print_timings:       total time = 21121.34 ms
# Llama.generate: prefix-match hit
#  89%|████████████████████████████████████████████████▏     | 100/112 [30:34<04:19, 21.59s/it]
# llama_print_timings:        load time =  6919.55 ms
# llama_print_timings:      sample time =   180.30 ms /   256 runs   (    0.70 ms per token,  1419.86 tokens per second)
# llama_print_timings: prompt eval time =  6890.45 ms /   142 tokens (   48.52 ms per token,    20.61 tokens per second)
# llama_print_timings:        eval time = 13786.80 ms /   255 runs   (   54.07 ms per token,    18.50 tokens per second)
# llama_print_timings:       total time = 21260.46 ms
# Llama.generate: prefix-match hit
#  90%|████████████████████████████████████████████████▋     | 101/112 [30:58<04:04, 22.26s/it]
# llama_print_timings:        load time =  6919.55 ms
# llama_print_timings:      sample time =   181.10 ms /   256 runs   (    0.71 ms per token,  1413.61 tokens per second)
# llama_print_timings: prompt eval time =  9133.63 ms /   189 tokens (   48.33 ms per token,    20.69 tokens per second)
# llama_print_timings:        eval time = 14085.04 ms /   255 runs   (   55.24 ms per token,    18.10 tokens per second)
# llama_print_timings:       total time = 23811.39 ms
# Llama.generate: prefix-match hit
#  91%|█████████████████████████████████████████████████▏    | 102/112 [31:17<03:33, 21.37s/it]
# llama_print_timings:        load time =  6919.55 ms
# llama_print_timings:      sample time =    92.11 ms /   131 runs   (    0.70 ms per token,  1422.17 tokens per second)
# llama_print_timings: prompt eval time = 11978.93 ms /   247 tokens (   48.50 ms per token,    20.62 tokens per second)
# llama_print_timings:        eval time =  7010.92 ms /   130 runs   (   53.93 ms per token,    18.54 tokens per second)
# llama_print_timings:       total time = 19302.20 ms
# Llama.generate: prefix-match hit
#  92%|█████████████████████████████████████████████████▋    | 103/112 [31:36<03:05, 20.60s/it]
# llama_print_timings:        load time =  6919.55 ms
# llama_print_timings:      sample time =   146.16 ms /   207 runs   (    0.71 ms per token,  1416.26 tokens per second)
# llama_print_timings: prompt eval time =  7121.07 ms /   147 tokens (   48.44 ms per token,    20.64 tokens per second)
# llama_print_timings:        eval time = 11213.29 ms /   206 runs   (   54.43 ms per token,    18.37 tokens per second)
# llama_print_timings:       total time = 18808.43 ms
# Llama.generate: prefix-match hit
#  93%|██████████████████████████████████████████████████▏   | 104/112 [32:00<02:51, 21.43s/it]
# llama_print_timings:        load time =  6919.55 ms
# llama_print_timings:      sample time =   180.50 ms /   256 runs   (    0.71 ms per token,  1418.27 tokens per second)
# llama_print_timings: prompt eval time =  8777.31 ms /   181 tokens (   48.49 ms per token,    20.62 tokens per second)
# llama_print_timings:        eval time = 14004.50 ms /   255 runs   (   54.92 ms per token,    18.21 tokens per second)
# llama_print_timings:       total time = 23371.03 ms
# Llama.generate: prefix-match hit
#  94%|██████████████████████████████████████████████████▋   | 105/112 [32:21<02:29, 21.39s/it]
# llama_print_timings:        load time =  6919.55 ms
# llama_print_timings:      sample time =   180.70 ms /   256 runs   (    0.71 ms per token,  1416.69 tokens per second)
# llama_print_timings: prompt eval time =  6944.81 ms /   144 tokens (   48.23 ms per token,    20.73 tokens per second)
# llama_print_timings:        eval time = 13769.77 ms /   255 runs   (   54.00 ms per token,    18.52 tokens per second)
# llama_print_timings:       total time = 21298.62 ms
# Llama.generate: prefix-match hit
#  95%|███████████████████████████████████████████████████   | 106/112 [32:49<02:19, 23.33s/it]
# llama_print_timings:        load time =  6919.55 ms
# llama_print_timings:      sample time =   166.54 ms /   234 runs   (    0.71 ms per token,  1405.09 tokens per second)
# llama_print_timings: prompt eval time = 13328.08 ms /   271 tokens (   49.18 ms per token,    20.33 tokens per second)
# llama_print_timings:        eval time = 13940.67 ms /   233 runs   (   59.83 ms per token,    16.71 tokens per second)
# llama_print_timings:       total time = 27831.68 ms
# Llama.generate: prefix-match hit
#  96%|███████████████████████████████████████████████████▌  | 107/112 [33:00<01:38, 19.64s/it]
# llama_print_timings:        load time =  6919.55 ms
# llama_print_timings:      sample time =     2.12 ms /     3 runs   (    0.71 ms per token,  1417.77 tokens per second)
# llama_print_timings: prompt eval time = 10899.81 ms /   223 tokens (   48.88 ms per token,    20.46 tokens per second)
# llama_print_timings:        eval time =   109.77 ms /     2 runs   (   54.88 ms per token,    18.22 tokens per second)
# llama_print_timings:       total time = 11047.25 ms
# Llama.generate: prefix-match hit
#  96%|████████████████████████████████████████████████████  | 108/112 [33:23<01:23, 20.77s/it]
# llama_print_timings:        load time =  6919.55 ms
# llama_print_timings:      sample time =   180.16 ms /   256 runs   (    0.70 ms per token,  1420.95 tokens per second)
# llama_print_timings: prompt eval time =  8904.89 ms /   183 tokens (   48.66 ms per token,    20.55 tokens per second)
# llama_print_timings:        eval time = 13918.24 ms /   255 runs   (   54.58 ms per token,    18.32 tokens per second)
# llama_print_timings:       total time = 23410.91 ms
# Llama.generate: prefix-match hit
#  97%|████████████████████████████████████████████████████▌ | 109/112 [33:51<01:08, 22.94s/it]
# llama_print_timings:        load time =  6919.55 ms
# llama_print_timings:      sample time =   129.53 ms /   185 runs   (    0.70 ms per token,  1428.30 tokens per second)
# llama_print_timings: prompt eval time = 17224.19 ms /   352 tokens (   48.93 ms per token,    20.44 tokens per second)
# llama_print_timings:        eval time = 10320.33 ms /   184 runs   (   56.09 ms per token,    17.83 tokens per second)
# llama_print_timings:       total time = 27988.91 ms
# Llama.generate: prefix-match hit
#  98%|█████████████████████████████████████████████████████ | 110/112 [34:18<00:48, 24.14s/it]
# llama_print_timings:        load time =  6919.55 ms
# llama_print_timings:      sample time =   179.34 ms /   256 runs   (    0.70 ms per token,  1427.50 tokens per second)
# llama_print_timings: prompt eval time = 12252.09 ms /   253 tokens (   48.43 ms per token,    20.65 tokens per second)
# llama_print_timings:        eval time = 14110.57 ms /   255 runs   (   55.34 ms per token,    18.07 tokens per second)
# llama_print_timings:       total time = 26955.84 ms
# Llama.generate: prefix-match hit
#  99%|█████████████████████████████████████████████████████▌| 111/112 [34:39<00:23, 23.33s/it]
# llama_print_timings:        load time =  6919.55 ms
# llama_print_timings:      sample time =   180.00 ms /   256 runs   (    0.70 ms per token,  1422.26 tokens per second)
# llama_print_timings: prompt eval time =  7214.44 ms /   150 tokens (   48.10 ms per token,    20.79 tokens per second)
# llama_print_timings:        eval time = 13625.10 ms /   255 runs   (   53.43 ms per token,    18.72 tokens per second)
# llama_print_timings:       total time = 21418.36 ms
# Llama.generate: prefix-match hit
# 100%|██████████████████████████████████████████████████████| 112/112 [34:49<00:00, 19.21s/it]
# llama_print_timings:        load time =  6919.55 ms
# llama_print_timings:      sample time =    38.63 ms /    55 runs   (    0.70 ms per token,  1423.58 tokens per second)
# llama_print_timings: prompt eval time =  6702.47 ms /   139 tokens (   48.22 ms per token,    20.74 tokens per second)
# llama_print_timings:        eval time =  2777.05 ms /    54 runs   (   51.43 ms per token,    19.45 tokens per second)
# llama_print_timings:       total time =  9613.69 ms
# 100%|██████████████████████████████████████████████████████| 112/112 [34:49<00:00, 18.66s/it]

# %%
#### DUMP OVERWRITE WARNING ####

llama_answers_file_path = './backups/answers_llama.pkl'

with open(llama_answers_file_path, 'wb') as file:
    pickle.dump(answers_llama, file)

print(f"Answers saved to {llama_answers_file_path}")
# Out:
# Answers saved to ./backups/answers_llama.pkl

# %%
docs_file_path = './backups/openai_embeddings/doc_embeddings.pkl'

with open(docs_file_path, 'rb') as file:
    docs = pickle.load(file)

print("Document embeddings loaded successfully.")
# Out:
# Document embeddings loaded successfully.

# %%
docs[1]['body']
# Out:
# '.W\nThis report is an analysis of 6300 acts of use\nin 104 technical libraries in the United Kingdom.\nLibrary use is only one aspect of the wider pattern of\ninformation use.  Information transfer in libraries is\nrestricted to the use of documents.  It takes no\naccount of documents used outside the library, still\nless of information transferred orally from person\nto person.  The library acts as a channel in only a\nproportion of the situations in which information is\ntransferred.\nTaking technical information transfer as a whole,\nthere is no doubt that this proportion is not the\nmajor one.  There are users of technical information -\nparticularly in technology rather than science -\nwho visit libraries rarely if at all, relying on desk\ncollections of handbooks, current periodicals and personal\ncontact with their colleagues and with people in other\norganizations.  Even regular library users also receive\ninformation in other ways.\n'

# %%
rel_set = {}
with open("../data/cisi/CISI.REL") as f:
    for l in f.readlines():
        qry_id = l.lstrip(" ").strip("\n").split("\t")[0].split(" ")[0]
        doc_id = l.lstrip(" ").strip("\n").split("\t")[0].split(" ")[-1]

        if qry_id in rel_set:
            rel_set[qry_id].append(doc_id)
        else:
            rel_set[qry_id] = []
            rel_set[qry_id].append(doc_id)

# %%
llama_answers_file_path = './backups/answers_llama.pkl'
with open(llama_answers_file_path, 'rb') as file:
    answers_llama = pickle.load(file)

# %%
# Implement BLEU evaluation function
def compute_bleu(references, candidate):
    smoothing = SmoothingFunction().method0
    return sentence_bleu(references, candidate, smoothing_function=smoothing)

# %%
# Implement ROUGE evaluation function
def compute_rouge(references, candidate):
    scorer = rouge_scorer.RougeScorer(['rouge1'], use_stemmer=True)
    total_score = 0

    # Compute ROUGE for each reference
    for reference in references:
        scores = scorer.score(reference, candidate)
        total_score += scores['rouge1'].fmeasure

    # Calculate average score
    average_score = total_score / len(references)
    return average_score

# %%
# Evaluate BLEU and ROUGE for each query

K = 30 # Number of most relevant docs to consider for scoring performance
total_bleu_score = 0.0
total_rouge_score = 0.0
num_queries = 0

for query_id, relevant_docs in tqdm(rel_set.items(), desc = 'Computing scores:'):
    query_text = queries[int(query_id)]
    response = answers_llama[int(query_id)]
    # print(query_id, query_text, "\n\nResponse:\n", response, "\n=========\nTopmost relevant Doc:\n", docs[int(relevant_docs[0])-1]['body'], "\n======\n")
    # print()
    
    # Evaluate using BLEU
    bleu_score = compute_bleu([docs[int(id)]['body'] for id in relevant_docs[:K]], response)
    total_bleu_score += bleu_score

    # Evaluate using ROUGE
    rouge_score = compute_rouge([docs[int(id)]['body'] for id in relevant_docs[:K]], response)
    total_rouge_score += rouge_score

    num_queries += 1
    
# Calculate mean scores
mean_bleu_score = total_bleu_score / num_queries
mean_rouge_score = total_rouge_score / num_queries

print(f"Mean BLEU Score: {mean_bleu_score:.4f}")
print(f"Mean ROUGE Score: {mean_rouge_score:.4f}")
# Out:
# Computing scores::   8%|███                                   | 6/76 [00:00<00:03, 18.32it/s]/Users/sanidhyasingal/Library/CloudStorage/GoogleDrive-ssingal@ucsd.edu/My Drive/UCSD/Notes/4th Quarter - Fall 2023/MED 277 - Intro to BioNLP/venv/lib/python3.9/site-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /Users/sanidhyasingal/Library/CloudStorage/GoogleDrive-ssingal@ucsd.edu/My Drive/UCSD/Notes/4th Quarter - Fall 2023/MED 277 - Intro to BioNLP/venv/lib/python3.9/site-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /Users/sanidhyasingal/Library/CloudStorage/GoogleDrive-ssingal@ucsd.edu/My Drive/UCSD/Notes/4th Quarter - Fall 2023/MED 277 - Intro to BioNLP/venv/lib/python3.9/site-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# Computing scores:: 100%|█████████████████████████████████████| 76/76 [00:04<00:00, 16.81it/s]
# Mean BLEU Score: 0.7199
# Mean ROUGE Score: 0.2061
